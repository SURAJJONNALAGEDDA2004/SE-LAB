# %% [markdown]
# <a href="https://colab.research.google.com/github/SURAJJONNALAGEDDA2004/SE-LAB/blob/main/Software_Eng_Lab_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

def quadratic_weather_model(time, a, b, c):
  temperature = a * (time**2) + b * time + c
  return temperature


def main():
  a = 1.3
  b = 3.4
  c = 2.3

  time_values = list(range(0, 51))
  temperature_values = [
      quadratic_weather_model(t, a, b, c) for t in time_values
  ]

  plt.figure(figsize=(8, 6))
  plt.plot(time_values, temperature_values, marker='o', linestyle='-')
  plt.title('Temperature Variation Over Time')
  plt.xlabel('Time')
  plt.ylabel('Temperature')
  plt.grid(True)
  plt.xlim(0, 50)
  plt.ylim(min(temperature_values) - 5, max(temperature_values) + 5)
  plt.show()


if __name__ == "__main__":
  main()

# %%
import matplotlib.pyplot as plt


def quadratic_weather_model(time, a, b, c):
  temperature = a * (time**2) + b * time + c
  return temperature


def main():
  a = float(input("Enter the value of a: "))
  b = float(input("Enter the value of b: "))
  c = float(input("Enter the value of c: "))

  time_values = list(range(5, 20))
  temperature_values = [
      quadratic_weather_model(t, a, b, c) for t in time_values
  ]

  plt.figure(figsize=(8, 6))
  plt.plot(time_values, temperature_values, marker='o', linestyle='-')
  plt.title('Temperature Variation Over Time')
  plt.xlabel('Time')
  plt.ylabel('Temperature')
  plt.grid(True)
  plt.xlim(0, 30)
  plt.ylim(min(temperature_values) - 5, max(temperature_values) + 5)
  plt.show()


if __name__ == "__main__":
  main()
# Out:
# Enter the value of a: 2.3
# Enter the value of b: 3.4
# Enter the value of c: 4.5

# %%
import matplotlib.pyplot as plt


def quadratic_weather_model(time, a, b, c):
  temperature = a * (time**2) + b * time + c
  return temperature


def main():
  with open('value.txt', mode='r') as file:
    a, b, c = map(float, file.readline().split())

  time_values = list(range(0, 20))
  temperature_values = [
      quadratic_weather_model(t, a, b, c) for t in time_values
  ]

  plt.figure(figsize=(8, 6))
  plt.plot(time_values, temperature_values, marker='o', linestyle='-')
  plt.title('Temperature Variation Over Time')
  plt.xlabel('Time')
  plt.ylabel('Temperature')
  plt.grid(True)
  plt.xlim(0, 25)
  plt.ylim(min(temperature_values) - 5, max(temperature_values) + 5)
  plt.show()


if __name__ == "__main__":
  main()

# %%
import matplotlib.pyplot as plt

def quadratic_weather_model(time, a, b, c):
    temperature = a * (time ** 2) + b * time + c
    return temperature

def main():


    try:
        with open('values.txt', 'r') as file:
            lines = file.readlines()

        time_values = list(range(0, 20))
        plt.figure(figsize=(8, 6))

        for line in lines:
            coefficients = line.split()
            a, b, c = map(float, coefficients)

            temperature_values = [quadratic_weather_model(t, a, b, c) for t in time_values]

            plt.plot(time_values, temperature_values, marker='o', linestyle='-', label=f'a={a}, b={b}, c={c}')

        plt.title('Temperature Variation Over Time')
        plt.xlabel('Time')
        plt.ylabel('Temperature')
        plt.grid(True)
        plt.xlim(0, 20)
        plt.legend()
        plt.show()

    except FileNotFoundError:
        print("File not found. Please make sure 'coefficients_multiple.txt' exists.")

if __name__ == "__main__":
    main()

# %%
import matplotlib.pyplot as plt
import numpy as np

a_user = int(input("Enter the value of a: "))
b_user = int(input("Enter the value of b: "))
c_user = int(input("Enter the value of c: "))

x = np.linspace(-10, 10, 400)

y1_user = a_user * x**2 + b_user * x + c_user

plt.plot(x, y1_user, label=f'User Input: {a_user}x^2 + {b_user}x + {c_user}')

a_fixed = 5
b_fixed = -5
c_fixed = 3

y2_fixed = a_fixed * x**2 + b_fixed * x + c_fixed

plt.plot(x, y2_fixed, label=f'Fixed Constants: {a_fixed}x^2 + {b_fixed}x + {c_fixed}')
plt.title('Plot of the quadratic functions')
plt.xlabel('Temperature')
plt.ylabel('Time')

plt.legend()
plt.grid(True)
plt.show()
# Out:
# Enter the value of a: 3
# Enter the value of b: 6
# Enter the value of c: 2
